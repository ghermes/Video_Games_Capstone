# %% [markdown]
# Sourcing and Loading Data

# %%
import numpy as np
import pandas as pd 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
import seaborn as sns 
import statsmodels.api as sm 
from statsmodels.graphics.api import abline_plot 
from sklearn.metrics import mean_squared_error, r2_score 
from sklearn.model_selection import train_test_split 
from sklearn import linear_model, preprocessing 
import warnings # For handling error messages 
warnings.simplefilter(action="ignore", category=FutureWarning)
warnings.filterwarnings(action="ignore", module="scipy", message="^internal gelsd")

# %%
data = pd.read_csv('VideoGamesData.csv')

# %%
data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count  User_Score  User_Count Developer Rating
# 0          51.0         8.0       322.0  Nintendo      E
# 1           NaN         NaN         NaN       NaN    NaN
# 2          73.0         8.3       709.0  Nintendo      E
# 3          73.0         8.0       192.0  Nintendo      E
# 4           NaN         NaN         NaN       NaN    NaN

# %%
data.tail()
# Out:
#                                 Name Platform  Year_of_Release       Genre  \
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0      Action
# 16715               LMA Manager 2007     X360           2006.0      Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0   Adventure
# 16717               Spirits & Spells      GBA           2003.0    Platform
# 16718            Winning Post 8 2016      PSV           2016.0  Simulation
#
#           Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 16714    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
# 16715   Codemasters      0.00      0.01      0.00          0.0          0.01
# 16716  Idea Factory      0.00      0.00      0.01          0.0          0.01
# 16717       Wanadoo      0.01      0.00      0.00          0.0          0.01
# 16718    Tecmo Koei      0.00      0.00      0.01          0.0          0.01
#
#        Critic_Score  Critic_Count  User_Score  User_Count Developer Rating
# 16714           NaN           NaN         NaN         NaN       NaN    NaN
# 16715           NaN           NaN         NaN         NaN       NaN    NaN
# 16716           NaN           NaN         NaN         NaN       NaN    NaN
# 16717           NaN           NaN         NaN         NaN       NaN    NaN
# 16718           NaN           NaN         NaN         NaN       NaN    NaN

# %% [markdown]
# Remove unneeded columns

# %%
df = pd.DataFrame(data, columns= ['Name', 'Platform', 'Genre', 'Publisher', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'])
df.head()
# Out:
#                        Name Platform         Genre Publisher  NA_Sales  \
# 0                Wii Sports      Wii        Sports  Nintendo     41.36
# 1         Super Mario Bros.      NES      Platform  Nintendo     29.08
# 2            Mario Kart Wii      Wii        Racing  Nintendo     15.68
# 3         Wii Sports Resort      Wii        Sports  Nintendo     15.61
# 4  Pokemon Red/Pokemon Blue       GB  Role-Playing  Nintendo     11.27
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     28.96      3.77         8.45         82.53
# 1      3.58      6.81         0.77         40.24
# 2     12.76      3.79         3.29         35.52
# 3     10.93      3.28         2.95         32.77
# 4      8.89     10.22         1.00         31.37

# %% [markdown]
# Cleaning, transforming, and visualizing Dataframe

# %%
df.dtypes
# Out:
# Name             object
# Platform         object
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %% [markdown]
# Check for/remove nulls

# %%
df.isnull().values.any()
# Out:
# True

# %%
df = df.dropna() 
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# Check for/remove duplicates

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Summary

# %%
df.describe()
# Out:
#            NA_Sales      EU_Sales      JP_Sales   Other_Sales  Global_Sales
# count  16663.000000  16663.000000  16663.000000  16663.000000  16663.000000
# mean       0.263598      0.145202      0.077805      0.047446      0.534302
# std        0.814619      0.504016      0.309306      0.186985      1.550158
# min        0.000000      0.000000      0.000000      0.000000      0.010000
# 25%        0.000000      0.000000      0.000000      0.000000      0.060000
# 50%        0.080000      0.020000      0.000000      0.010000      0.170000
# 75%        0.240000      0.110000      0.040000      0.030000      0.470000
# max       41.360000     28.960000     10.220000     10.570000     82.530000

# %% [markdown]
# Pre-Processing - We're going to concentrate on North American sales

# %%
df = pd.DataFrame(df, columns= ['Platform', 'Genre', 'Publisher', 'NA_Sales']) 
df
# Out:
#       Platform         Genre     Publisher  NA_Sales
# 0          Wii        Sports      Nintendo     41.36
# 1          NES      Platform      Nintendo     29.08
# 2          Wii        Racing      Nintendo     15.68
# 3          Wii        Sports      Nintendo     15.61
# 4           GB  Role-Playing      Nintendo     11.27
# ...        ...           ...           ...       ...
# 16714      PS3        Action    Tecmo Koei      0.00
# 16715     X360        Sports   Codemasters      0.00
# 16716      PSV     Adventure  Idea Factory      0.00
# 16717      GBA      Platform       Wanadoo      0.01
# 16718      PSV    Simulation    Tecmo Koei      0.00
#
# [16663 rows x 4 columns]

# %% [markdown]
# Scale dataset

# %%
from sklearn.preprocessing import StandardScaler 
scaler = StandardScaler() 

# save the features we don't want to scale
var1 = df['Genre']  
var2 = df['Platform']
var3 = df['Publisher'] 

# fit scale to data 
scaler.fit(df.drop(['Platform', 'Genre', 'Publisher'], axis = 1)) 
scaled_values = scaler.transform(df.drop(['Platform', 'Genre', 'Publisher'], axis = 1)) 
df = pd.DataFrame(scaled_values) 

# merge saved features to scaled features 
df['Genre'] = var1
df['Platform'] = var2 
df['Publisher'] = var3

print(df)
# Out:
#                0         Genre Platform           Publisher
# 0      50.450162        Sports      Wii            Nintendo
# 1      35.375169      Platform      NES            Nintendo
# 2      18.925257        Racing      Wii            Nintendo
# 3      18.839325        Sports      Wii            Nintendo
# 4      13.511518  Role-Playing       GB            Nintendo
# ...          ...           ...      ...                 ...
# 16658  -0.323594        Action     X360  Namco Bandai Games
# 16659  -0.323594        Sports       PC   DTP Entertainment
# 16660  -0.323594        Sports       DS             Ubisoft
# 16661  -0.311318     Adventure      PSV           Nitroplus
# 16662  -0.323594           NaN      NaN                 NaN
#
# [16663 rows x 4 columns]

# %%
df = df.rename(columns={0: 'NA_Sales'}) 
df
# Out:
#         NA_Sales         Genre Platform           Publisher
# 0      50.450162        Sports      Wii            Nintendo
# 1      35.375169      Platform      NES            Nintendo
# 2      18.925257        Racing      Wii            Nintendo
# 3      18.839325        Sports      Wii            Nintendo
# 4      13.511518  Role-Playing       GB            Nintendo
# ...          ...           ...      ...                 ...
# 16658  -0.323594        Action     X360  Namco Bandai Games
# 16659  -0.323594        Sports       PC   DTP Entertainment
# 16660  -0.323594        Sports       DS             Ubisoft
# 16661  -0.311318     Adventure      PSV           Nitroplus
# 16662  -0.323594           NaN      NaN                 NaN
#
# [16663 rows x 4 columns]

# %% [markdown]
# Create dummy features

# %%
X = df[['Genre', 'Platform', 'Publisher']] 
Y = df['NA_Sales'] 
X = pd.get_dummies(data=X, drop_first=True)

# %% [markdown]
# Split data into training and testing sets

# %%
 from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = .20, random_state = 42)

# %% [markdown]
# Modeling

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV

n_estimators = [int(x) for x in np.linspace(start = 10, stop = 100, num = 10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

prac_model = RandomForestRegressor()
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
prac_model = RandomizedSearchCV(estimator = prac_model, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
prac_model.fit(X_train, y_train)
prac_model.best_params_
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  33 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=-1)]: Done 154 tasks      | elapsed: 32.3min
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed: 64.6min finished
# {'n_estimators': 70,
#  'min_samples_split': 10,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 80,
#  'bootstrap': True}

# %%
# Model #1: Random Forest Regressor to predict sales
from sklearn.metrics import f1_score
model1 = RandomForestRegressor(n_estimators = 70, min_samples_split = 10, min_samples_leaf = 2, max_features = 'sqrt', 
            max_depth = 80, bootstrap = True)  
model1.fit(X_train, y_train) 
y_pred = model1.predict(X_test)

# %%
from sklearn import metrics

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.34266039607172505
# Mean Squared Error: 1.4257775904054613
# Root Mean Squared Error: 1.1940592909924788

# %%
# Model Feature Importance 
# get importance
importance = model1.feature_importances_

# %%
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# Out:
# Feature: 0, Score: 0.01649
# Feature: 1, Score: 0.00903
# Feature: 2, Score: 0.01673
# Feature: 3, Score: 0.05197
# Feature: 4, Score: 0.01626
# Feature: 5, Score: 0.03037
# Feature: 6, Score: 0.02954
# Feature: 7, Score: 0.06379
# Feature: 8, Score: 0.01131
# Feature: 9, Score: 0.01937
# Feature: 10, Score: 0.01007
# Feature: 11, Score: 0.00000
# Feature: 12, Score: 0.00851
# Feature: 13, Score: 0.00012
# Feature: 14, Score: 0.01866
# Feature: 15, Score: 0.06720
# Feature: 16, Score: 0.01450
# Feature: 17, Score: 0.00706
# Feature: 18, Score: 0.00237
# Feature: 19, Score: 0.00000
# Feature: 20, Score: 0.00725
# Feature: 21, Score: 0.08687
# Feature: 22, Score: 0.00003
# Feature: 23, Score: 0.00961
# Feature: 24, Score: 0.00000
# Feature: 25, Score: 0.00889
# Feature: 26, Score: 0.01110
# Feature: 27, Score: 0.00968
# Feature: 28, Score: 0.00531
# Feature: 29, Score: 0.00976
# Feature: 30, Score: 0.00529
# Feature: 31, Score: 0.00127
# Feature: 32, Score: 0.00004
# Feature: 33, Score: 0.01586
# Feature: 34, Score: 0.00000
# Feature: 35, Score: 0.00000
# Feature: 36, Score: 0.02403
# Feature: 37, Score: 0.00842
# Feature: 557, Score: 0.00001
# Feature: 558, Score: 0.00000
# Feature: 559, Score: 0.00000
# Feature: 560, Score: 0.00000
# Feature: 561, Score: 0.00000
# Feature: 562, Score: 0.00001
# Feature: 563, Score: 0.00000
# Feature: 564, Score: 0.00000
# Feature: 565, Score: 0.00000
# Feature: 566, Score: 0.00000
# Feature: 567, Score: 0.00005
# Feature: 568, Score: 0.00000
# Feature: 569, Score: 0.00283
# Feature: 570, Score: 0.00001
# Feature: 571, Score: 0.00000
# Feature: 572, Score: 0.00000
# Feature: 573, Score: 0.00019
# Feature: 574, Score: 0.00119
# Feature: 575, Score: 0.00000
# Feature: 576, Score: 0.00000
# Feature: 577, Score: 0.00000
# Feature: 578, Score: 0.00010
# Feature: 579, Score: 0.00000
# Feature: 580, Score: 0.00000
# Feature: 581, Score: 0.00000
# Feature: 582, Score: 0.00001
# Feature: 583, Score: 0.00000
# Feature: 584, Score: 0.00000
# Feature: 585, Score: 0.00000
# Feature: 586, Score: 0.00105
# Feature: 587, Score: 0.00000
# Feature: 588, Score: 0.00000
# Feature: 589, Score: 0.00067
# Feature: 590, Score: 0.00000
# Feature: 591, Score: 0.00000
# Feature: 592, Score: 0.00000
# Feature: 593, Score: 0.00186
# Feature: 594, Score: 0.00000
# Feature: 595, Score: 0.00000
# Feature: 596, Score: 0.00000
# Feature: 597, Score: 0.00000
# Feature: 598, Score: 0.00000
# Feature: 599, Score: 0.00004
# Feature: 600, Score: 0.00000
# Feature: 601, Score: 0.00000
# Feature: 602, Score: 0.00001
# Feature: 603, Score: 0.00000
# Feature: 604, Score: 0.00001
# Feature: 605, Score: 0.00000
# Feature: 606, Score: 0.00002
# Feature: 607, Score: 0.00001
# Feature: 608, Score: 0.00000
# Feature: 609, Score: 0.00000
# Feature: 610, Score: 0.00088
# Feature: 611, Score: 0.00013
# Feature: 612, Score: 0.00004
# Feature: 613, Score: 0.00000
# Feature: 614, Score: 0.00000
# Feature: 615, Score: 0.00000
# Feature: 616, Score: 0.00000
# Feature: 617, Score: 0.00000
# Feature: 618, Score: 0.00000
# Feature: 619, Score: 0.00000
# Feature: 620, Score: 0.00000
# Feature: 621, Score: 0.00000

# %%
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()

# %%
def feature_importance(model, X, top):
        importances = model.feature_importances_
        indices = np.argsort(importances)[::-1]
        ordered = importances[indices].reshape(-1,)
        cols = X.columns[indices]
        return pd.DataFrame({'variables': cols[:top], 'importances':ordered[:top]}).plot.bar(x='variables', y='importances')

# %%
feature_importance(model1, X, 20)
# Out:
# <AxesSubplot:xlabel='variables'>

# %%
#Model #2: SVM Regressor to predict sales
from sklearn.svm import SVR 
model2 = SVR(kernel='rbf') 
model2.fit(X_train, y_train) 
y_pred = model2.predict(X_test)

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.29969847264314853
# Mean Squared Error: 1.4899946907997343
# Root Mean Squared Error: 1.220653386838268
